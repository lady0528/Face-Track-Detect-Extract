# %% [markdown]
# <a href="https://colab.research.google.com/github/lady0528/Face-Track-Detect-Extract/blob/master/FVR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip /content/drive/MyDrive/fingerveinrecognition.zip
# Out:
# Archive:  /content/drive/MyDrive/fingerveinrecognition.zip
#    creating: fingerveinrecognition/
#    creating: fingerveinrecognition/fingerveinrecognition-37/
#    creating: fingerveinrecognition/fingerveinrecognition-37/datasets/
#   inflating: fingerveinrecognition/fingerveinrecognition-37/datasets/datasets.py
#   inflating: fingerveinrecognition/fingerveinrecognition-37/datasets/FVUSM_filelist.txt
#   inflating: fingerveinrecognition/fingerveinrecognition-37/datasets/FVUSM_testlist_closeset.txt
#   inflating: fingerveinrecognition/fingerveinrecognition-37/datasets/FVUSM_testlist_openset.txt
#   inflating: fingerveinrecognition/fingerveinrecognition-37/datasets/FVUSM_trainlist_closeset.txt
#   inflating: fingerveinrecognition/fingerveinrecognition-37/datasets/FVUSM_trainlist_openset.txt
#   inflating: fingerveinrecognition/fingerveinrecognition-37/datasets/get_filelist.py
#   inflating: fingerveinrecognition/fingerveinrecognition-37/datasets/ROI_extration.py
# ...

# %%
# %cd /content/fingerveinrecognition/fingerveinrecognition-37
# Out:
# /content/fingerveinrecognition/fingerveinrecognition-37

# %%
# !tar zxvf /content/drive/MyDrive/FV-USM-processed.tgz
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# FV-USM-processed/094_1_10.bmp
# FV-USM-processed/036_4_02.bmp
# FV-USM-processed/007_1_08.bmp
# FV-USM-processed/018_1_07.bmp
# FV-USM-processed/050_1_09.bmp
# FV-USM-processed/070_3_09.bmp
# FV-USM-processed/008_3_11.bmp
# FV-USM-processed/064_2_04.bmp
# FV-USM-processed/011_1_07.bmp
# FV-USM-processed/001_2_04.bmp
# FV-USM-processed/088_1_02.bmp
# FV-USM-processed/076_2_01.bmp
# FV-USM-processed/084_2_05.bmp
# FV-USM-processed/019_1_03.bmp
# FV-USM-processed/065_2_02.bmp
# FV-USM-processed/101_1_04.bmp
# FV-USM-processed/059_2_10.bmp
# FV-USM-processed/065_2_01.bmp
# FV-USM-processed/048_2_07.bmp
# FV-USM-processed/004_4_07.bmp
# FV-USM-processed/035_3_03.bmp
# FV-USM-processed/011_2_06.bmp
# FV-USM-processed/123_3_03.bmp
# FV-USM-processed/066_1_08.bmp
# FV-USM-processed/077_3_10.bmp
# FV-USM-processed/066_1_11.bmp
# FV-USM-processed/080_4_06.bmp
# FV-USM-processed/028_2_01.bmp
# FV-USM-processed/033_2_01.bmp
# FV-USM-processed/004_2_03.bmp
# ...

# %%
# !pip install ptflops
# Out:
# ...
#   Created wheel for ptflops: filename=ptflops-0.6.4-cp36-none-any.whl size=8573 sha256=a5502d3574b8c9f5919c9e0169a7bd0d6b0453e4a73eed2a625f565ca7e41459
#   Stored in directory: /root/.cache/pip/wheels/4a/98/93/570ea2949d33c4c0960a8e85bc8725fe37706b933d4e5b173b
# Successfully built ptflops
# ...

# %%
# %%shell
#
# bash /content/fingerveinrecognition/fingerveinrecognition-37/run.sh
# Out:
# Namespace(batch_size=4, dataset='FVUSM', feature_dim=128, gamma_cos=1.0, gamma_tri=1.0, hard_margin=0.2, k=4, log_interval=10, loss='tripletCosface', lr=0.01, lr_decay=0.1, lr_fc=0.1, m=0.2, max_epoch=60, momentum=0.9, network='resnet18', openset=True, p=8, plot=False, pretrained=True, s=15.0, seed=1, wd=0.0005)
# Namespace(batch_size=4, dataset='FVUSM', feature_dim=128, gamma_cos=1.0, gamma_tri=6.0, hard_margin=0.2, k=4, log_interval=10, loss='tripletCosface', lr=0.01, lr_decay=0.1, lr_fc=0.1, m=0.2, max_epoch=60, momentum=0.9, network='resnet18', openset=True, p=8, plot=False, pretrained=True, s=15.0, seed=1, wd=0.0005)
# 02:11:15 Training started.
# 02:11:15 Epoch:[0]-[0/92] batchLoss:9.4815(cosface:8.7543, triplet:0.7272) averLoss:9.4815 batchAcc:0.00% averAcc:0.00%, numTriplet:86
# 02:11:16 Epoch:[0]-[10/92] batchLoss:9.5274(cosface:8.8618, triplet:0.6656) averLoss:9.3982 batchAcc:0.00% averAcc:0.28%, numTriplet:73
# ...

# %% [markdown]
# # 新段落
